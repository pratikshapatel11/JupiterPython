# %% [markdown]
# #function
# it is a set of block of code to perform specific task

# %% [markdown]
# # It is defined using the 'def' keyword, followed by the function name and parameters.
#
# def greet(name):
#     """This function greets the person passed in as a parameter."""
#     return f"Hello, {name}!"
#
# # Example usage
# print(greet("Alice"))
