# %%
l=[10,20,30,"hello",10.5]
print(l)
print(type(l))
print(l[-2])  #index
l[0]=1000     #mutable
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5]
# <class 'list'>
# hello
# [1000, 20, 30, 'hello', 10.5]

# %%
#iteration
#direct iteration 
l=[10,20,30,"hello",10.5]
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# hello
# 10.5

# %%
#indirect iteration
l=[10,20,30,"hello",10.5]
for i in range(len(l)):
    print(i,l[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 hello
# 4 10.5

# %%
n=5
for i in range(n):
    for j in range(n):
      if i==0 or i==n-1 or j==0 or j==n-1:
         print(chr(65+j),end=" ")
      else:
          print("^",end=" ")
    print( )
# Out:
# A B C D E
# A ^ ^ ^ E
# A ^ ^ ^ E
# A ^ ^ ^ E
# A B C D E

# %%
#methods
#append
#add elements to an existing list object
#append()
#listobj.append(value/element)
#new element --position
l=[10,20,30,"hello",40]
l.append(1000)
print(l)
# Out:
# [10, 20, 30, 'hello', 40, 1000]

# %%
l=[10,20,30,"hello",40]
l.append(10.5)
print(l)
# Out:
# [10, 20, 30, 'hello', 40, 10.5]

# %%
l=[10,20,30,"hello",40]
l.append([100,200,300,"decode"])
print(l)
# Out:
# [10, 20, 30, 'hello', 40, [100, 200, 300, 'decode']]

# %%
#create a homognous list with 4 element (add element at runtime)
l=[]
for i in range(4):
    n=int(input("enter any number"))
    l.append(n)
    print(l)
# Out:
# enter any number 10
# [10]
# enter any number 20
# [10, 20]
# enter any number 30
# [10, 20, 30]
# enter any number 521
# [10, 20, 30, 521]

# %%
# 1,27,125,343,729
l=[]
for i in range(1,10,2):
     l.append(i**3)
print(l)
# Out:
# [1, 27, 125, 343, 729]

# %%
l=[5,2,1,6,3,4]
for i in l:

# %%
#sorted(sequence,[reverce=false])
#it always return newlist
#by default always return element 
#ascending order
l=[10,1,12,13,5]
l1=sorted(l)
print(l1)
# Out:
# [1, 5, 10, 12, 13]

# %%
l=[10,1,7,5,5,7,7,2,4,6,5,7,3,9,8,7]
l1=sum(l)/len(l)
print(l1)
l2=sorted(l)
print(l2)
# Out:
# 5.8125
# [1, 2, 3, 4, 5, 5, 5, 6, 7, 7, 7, 7, 7, 8, 9, 10]

# %%
l=[10,1,7,5,5,7,7,2,4,6,5,7,3,9,8,7]
sum=0
count=0
for i in l:
    sum=sum+i
    count=count+1
mean=sum/count
print(mean)
sorted_list=sorted(l)
print(sorted_list)
n=len(sorted_list)
if n%2!=0:
    median=sorted_list[n//2]
else:
    median=(sorted_list[n//2-1])/2
print(median)
# Out:
# 5.8125
# [1, 2, 3, 4, 5, 5, 5, 6, 7, 7, 7, 7, 7, 8, 9, 10]
# 3.0

# %%
#insert
#listobj.insert(position,value/element)
l=[10,20,"hello",300,10.5]
l.insert(2,"decode")
print(l)
# Out:
# [10, 20, 'decode', 'hello', 300, 10.5]

# %%
#extend
#listobj.extend(sequencetypr)
l=[10,20,30,"hello",10.5]
l.extend([100,200,300,"decode",100.5])
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100, 200, 300, 'decode', 100.5]

# %%
l=[10,20,30,"hello",10.5]
l.extend([100])
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100]

# %%
l=[10,20,30,"hello",10.5]
l.extend("decode")
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 'd', 'e', 'c', 'o', 'd', 'e']

# %%
l=[10,20,30,"hello",10.5]
l.extend((100,200,300))
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100, 200, 300]

# %%
#remove elements from an existing list 
#pop()
#listobj.pop([position])
#by default : -1
#always return elementss
l=[10,20,30,"decode",10.5]
print(l.pop())
print(l)
# Out:
# 10.5
# [10, 20, 30, 'decode']

# %%
l=[10,20,30,"decode",10.5]
print(l.pop(2))
print(l)
# Out:
# 30
# [10, 20, 'decode', 10.5]

# %%
#del
#del listobj[position]
l=[10,20,30,"decode",10.5]
del l[3]
print(l)
# Out:
# [10, 20, 30, 10.5]

# %%
#remove
#listobj.remove(value)
l=[10,20,30,"decode",10.5]
l.remove("decode")
print(l)
# Out:
# [10, 20, 30, 10.5]

# %%
l=[10,20,30,40,10,"hello",10.5]
l.remove(10)
print(l)
# Out:
# [20, 30, 40, 10, 'hello', 10.5]

# %%
#clear()
#listobj.clear()
[10,20,30,"decode",10.5]
l.clear()
print(l)
# Out:
# []

# %%
l=[100,200,300,[1000,2000,"hello",["A","B"],10.5],"decode",117]
li=["bhp","ind"]

# %%
#sort
#listobj.sort([reverse=false])
l=[10,20,1,19]
l.sort()
print(l)
# Out:
# [1, 10, 19, 20]

# %%
l=[10,20,1,19]
l.sort(reverse=True)
print(l)
# Out:
# [20, 19, 10, 1]

# %%
l=[10,20,1,19]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]>l[j]:
            l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [1, 10, 19, 20]

# %%
#sum of two integer in a given list
l=[1,11,6,7,2,8]
target=18
for i in range(len(l)) 

#output -[1,3]
# Out:
# [1, 11, 6, 7, 2, 8]

# %%
#index
#listobj.index,[start],[stop]
l=[10,20,30,40,"hello",10,10,20,30,10]
print(l.index(10))
print(l.index(10,1))
print(l.index(10,5))
# Out:
# 0
# 5
# 5

# %%
l=[[30,70,60],[100,300,200,400],[70,60,80]]
l1=[]
for i in l:
    for j in range(len(i)):
        for k in range(j+1,len(i)):
            if i[j]>i[k]:
                i[j],i[k]=i[k],i[j]
                l1.append(i[-2])
print(l1)
# Out:
# [60, 300, 70]
